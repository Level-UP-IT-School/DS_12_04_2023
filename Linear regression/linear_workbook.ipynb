# %% [markdown]
# <img src="https://imgur.com/orZWHly.png" alt="Drawing" style="width: 800px;"/>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("penguins.csv")
data.head()
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0    0       2         39.1          18.7           181.0      3750.0    1
# 1    0       2         39.5          17.4           186.0      3800.0    0
# 2    0       2         40.3          18.0           195.0      3250.0    0
# 3    0       2         36.7          19.3           193.0      3450.0    0
# 4    0       2         39.3          20.6           190.0      3650.0    1

# %%
X = data[['масса тела']]
y = data['длина плавника']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
plt.scatter(X_train, y_train)

plt.xlabel("масса тела (мм)")
plt.ylabel("длина плавника (мм)")

plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.01543413])

# %%
lr.intercept_
# Out:
# 136.06434327390724

# %%
plt.scatter(X_train, y_train)

def f_line(x):
    return lr.coef_*x+lr.intercept_

x = [2500, 6000]
y = f_line(x)
plt.plot(x, y)

plt.xlabel("масса тела (мм)")
plt.ylabel("длина плавника (мм)")

plt.show()

# %%
plt.scatter(X_test, y_test)

def f_line(x):
    return lr.coef_*x+lr.intercept_

x = [2500, 6000]
y = f_line(x)
plt.plot(x, y)

plt.xlabel("масса тела (мм)")
plt.ylabel("длина плавника (мм)")

plt.show()

# %%
y_train_predicted = lr.predict(X_train)

y_test_predicted = lr.predict(X_test)

# %%
np.array(y_test)
# Out:
# array([189., 192., 192., 189., 190., 184., 216., 210., 195., 218., 222.,
#        197., 208., 195., 190., 214., 197., 190., 191., 230., 203., 190.,
#        198., 211., 184., 210., 184., 213., 219., 230., 214., 190., 198.,
#        212., 190., 210., 218., 214., 185., 187., 195., 196., 187., 191.,
#        195., 215., 206., 213., 210., 215.])

# %%
np.array(y_test_predicted)
# Out:
# array([187.76869532, 190.08381556, 177.73650761, 197.02917628,
#        189.31210881, 187.38284195, 209.37648424, 204.74624375,
#        186.22528183, 212.46331122, 224.81061918, 193.55649592,
#        200.88771002, 197.80088303, 189.31210881, 210.91989773,
#        209.76233761, 197.02917628, 207.061364  , 225.58232592,
#        199.34429653, 201.65941677, 194.32820267, 210.14819098,
#        180.05162785, 207.061364  , 189.69796219, 226.35403267,
#        217.09355171, 220.95208544, 207.83307074, 193.17064255,
#        195.09990942, 211.3057511 , 191.62722906, 208.60477749,
#        217.86525845, 212.07745785, 182.36674809, 193.17064255,
#        202.43112351, 208.60477749, 185.45357508, 193.17064255,
#        208.21892412, 213.23501797, 197.02917628, 203.97453701,
#        210.14819098, 220.95208544])

# %%
plt.scatter(X_test[:15], y_test[:15])

plt.scatter(X_test[:5], y_test_predicted[:5])

def f_line(x):
    return lr.coef_*x+lr.intercept_

x = [2500, 6000]
y = f_line(x)
plt.plot(x, y)

plt.xlabel("масса тела (мм)")
plt.ylabel("длина плавника (мм)")

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(y_train_predicted, y_train), mean_absolute_error(y_test_predicted, y_test)
# Out:
# (5.6035738698968185, 5.245729655529532)

# %%
np.mean(np.abs(y_train_predicted-y_train))
# Out:
# 5.6035738698968185

# %%
mean_squared_error(y_train_predicted, y_train), mean_squared_error(y_test_predicted, y_test)
# Out:
# (46.98150124354771, 44.65671552348722)

# %%
np.mean((y_train_predicted-y_train)**2)
# Out:
# 46.98150124354771

# %%
X = data[['масса тела', "длина клюва"]]
y = data['длина плавника']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

x_points=X_train['масса тела']
y_points=X_train["длина клюва"]
z_points = y_train

ax.scatter(x_points, y_points, z_points)

ax.set_xlabel('масса тела')
ax.set_ylabel("длина клюва")
ax.set_zlabel("длина плавника")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predicted = lr.predict(X_train)

y_test_predicted = lr.predict(X_test)

# %%
lr.coef_
# Out:
# array([0.01269696, 0.54959592])

# %%
def f_plane(x1, x2):
    return lr.coef_[0]*x1 + lr.coef_[1]*x2 + lr.intercept_

# %%
X_train['длина клюва'].max()
# Out:
# 59.6

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

x_points=X_train['масса тела']
y_points=X_train["длина клюва"]
z_points = y_train

ax.scatter(x_points, y_points, z_points)

x, y = np.meshgrid(range(2800, 6350), range(30, 61))
z = np.array([f_plane(point_x, point_y) for point_x, point_y in zip(x, y)])

ax.plot_surface(x,y,z, alpha=0.2)

ax.set_xlabel('масса тела')
ax.set_ylabel("длина клюва")
ax.set_zlabel("длина плавника")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
